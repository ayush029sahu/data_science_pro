# %% [markdown]
# matplotlib(pyplot)-seaborn
# seaborn is a library that uses matplotlib underneath to plot grapg i.e-pyplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# displot-distribution plot(curve plot-histogram)

# %%
sns.distplot([0,1,2,3,4])
plt.show()
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_2780\2606807074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4])

# %% [markdown]
# plotting a distplot without the histogram

# %%
sns.distplot([0,1,2,3,4],hist=False)
plt.show()
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_2780\2961205058.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4],hist=False)
